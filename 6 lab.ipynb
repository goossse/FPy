# %% [markdown]
# #### 1

# %%
import re 
import pandas as pd
import numpy as np
books = pd.read_csv('books.csv')
books
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher
# 0    signal_processing     228          Wiley
# 1         data_science     235          Wiley
# ...

# %% [markdown]
# #### 2

# %%
b1 = books[books['Publisher'].str.count('(?i)[aeuioy]')==0 ]
b2 = books[books['Publisher'].str.count('(?i)[aeuioy]')==1 ]
b3 = pd.concat([b1, b2], ignore_index=True)
b3
# Out:
#                                         Title           Author       Genre  \
# 0  Image Processing & Mathematical Morphology      Shih, Frank        tech
# 1                    Complete Mastermind, The              BBC  nonfiction
# 2         Principles of Communication Systems  Taub, Schilling        tech
# 3                             Analysis, Vol I     Tao, Terence        tech
# 4                           False Impressions  Archer, Jeffery     fiction
# 5                        Prisoner of Birth, A  Archer, Jeffery     fiction
# 6                                         One    Bach, Richard  nonfiction
#
#             SubGenre  Height Publisher
# 0  signal_processing     241       CRC
# 1             trivia     178       BBC
# 2  signal_processing     240       TMH
# 3        mathematics     248       HBA
# 4              novel     177       Pan
# 5              novel     176       Pan
# 6      autobiography     172      Dell

# %% [markdown]
# #### 3

# %%
lettersstart = ('B','C','D','F','G','H','J','K','L','M','N','P','Q','R','S','T','V','W','X','Z')
lettersend = ('b','c','d','f','g','h','j','k','l','m','n','p','q','r','s','t','v','w','x','z')
books3 = books[books['Author'].str.split(', ').str.get(0).str.startswith(lettersstart, na = False)]
#books3
books3[books3['Author'].str.split(', ').str.get(0).str.endswith(lettersend, na = False)]
# Out:
#                                           Title            Author       Genre  \
# 1                                    Data Smart     Foreman, John        tech
# 2                      God Created the Integers  Hawking, Stephen        tech
# 3                             Superfreakonomics   Dubner, Stephen     science
# 4                                   Orientalism      Said, Edward  nonfiction
# 5    Nature of Statistical Learning Theory, The  Vapnik, Vladimir        tech
# ..                                          ...               ...         ...
# 200                    Tales of Beedle the Bard      Rowling, J K     fiction
# 201                 Girl with the Dragon Tattoo    Larsson, Steig     fiction
# 202           Girl who kicked the Hornet's Nest    Larsson, Steig     fiction
# 203                   Girl who played with Fire    Larsson, Steig     fiction
# 210                          Christmas Carol, A  Dickens, Charles     fiction
#
# ...

# %% [markdown]
# #### 4

# %%
books['VowelCount'] = books['Title'].str.count("(?i)[aeiouy]")
books[books.VowelCount == books.VowelCount.max()]
# Out:
#                                                  Title              Author  \
# 115  Clash of Civilizations and Remaking of the Wor...  Huntington, Samuel
#
#           Genre SubGenre  Height       Publisher  VowelCount
# 115  nonfiction  history     228  Simon&Schuster          17

# %% [markdown]
# #### 5

# %%
books[books['Title'].str.contains(r'\b\w{2}\b', na = False)]
# Out:
#                                           Title               Author  \
# 0                      Fundamentals of Wavelets     Goswami, Jaideva
# 5    Nature of Statistical Learning Theory, The     Vapnik, Vladimir
# 6              Integration of the Indian States           Menon, V P
# 9             How to Think Like Sherlock Holmes     Konnikova, Maria
# 10                      Data Scientists at Work  Sebastian Gutierrez
# ..                                          ...                  ...
# 190              History of England, Foundation       Ackroyd, Peter
# 191                              City of Djinns   Dalrymple, William
# 193                           More Tears to Cry        Sassoon, Jean
# 199                             Eyeless in Gaza       Huxley, Aldous
# 200                    Tales of Beedle the Bard         Rowling, J K
#
#           Genre           SubGenre  Height         Publisher  VowelCount
# ...

# %% [markdown]
# #### 6

# %%
books[books['Author'].str.split(',').str.get(1).str.contains('(?i)[bcdfghjklmnpqrstvwxz]{3}', na = False)]
# Out:
#                                       Title               Author       Genre  \
# 26            Beautiful and the Damned, The      Deb, Siddhartha  nonfiction
# 28    Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan     fiction
# 29   Complete Sherlock Holmes, The - Vol II  Doyle, Arthur Conan     fiction
# 56              Textbook of Economic Theory      Stonier, Alfred        tech
# 59            Data Structures Using C & C++    Tanenbaum, Andrew        tech
# 61      Principles of Communication Systems      Taub, Schilling        tech
# 62                                 Let Us C   Kanetkar, Yashwant        tech
# 89                             On Education    Russell, Bertrand  philosophy
# 112           History of Western Philosophy    Russell, Bertrand  philosophy
# 123                        Unpopular Essays    Russell, Bertrand  philosophy
# 172                           Pointers in C   Kanetkar, Yashwant        tech
# ...

# %% [markdown]
# #### 7

# %%
books['Last word'] = books.apply(lambda x: x['Title'].split(" ")[len(x["Title"].split(" "))-1], axis=1)
books['last word findall']=books['Title'].str.findall(r'\b(\w+)\W*$')
books
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher  VowelCount          Last word  \
# 0    signal_processing     228          Wiley           8           Wavelets
# ...

# %% [markdown]
# #### 8

# %%
books[books['Author'].str.split(', ').str.get(0).str.contains(r'\b\w{5}\b', na = False)]
# Out:
#                                       Title               Author       Genre  \
# 6          Integration of the Indian States           Menon, V P  nonfiction
# 14                        Age of Wrath, The       Eraly, Abraham  nonfiction
# 15                               Trial, The         Kafka, Frank     fiction
# 16             Statistical Decision Theory'          Pratt, John        tech
# 18                     New Machiavelli, The         Wells, H. G.     fiction
# 27                            Outsider, The        Camus, Albert     fiction
# 28    Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan     fiction
# 29   Complete Sherlock Holmes, The - Vol II  Doyle, Arthur Conan     fiction
# 30                   Wealth of Nations, The          Smith, Adam     science
# 33                      Tao of Physics, The       Capra, Fritjof     science
# 44                  Hidden Connections, The       Capra, Fritjof     science
# ...
